# %%
print('prueba de python ')
# Out:
# prueba de python

# %%
print(type(5))
print(type(5.0))
print(type('hola'))
print(type(True))
print(type(None))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombe = 'Ivan'
edad = 30
estatura = 1.75

# %%
print(nombe)
# Out:
# Ivan

# %%
nombre = 'transformers'
anno = 2007
visto = True
print('la pelicula ' + nombre + ' del año ' + str(anno) + ' se vio ' + ('correctamente' if visto else 'pe'))
# Out:
# la pelicula transformers del año 2007 se vio correctamente

# %%
peliculas = [
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]

annos = [
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]

vistas = [
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]

# %%
for i in range(len(peliculas)):
    print('la pelicula ' + peliculas[i] + ' del año ' + str(annos[i]) + ' se vio ' + ('correctamente' if vistas[i] else 'incorrectamente'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for i in range(len(peliculas)):
#       2     print('la pelicula ' + peliculas[i] + ' del año ' + str(annos[i]) + ' se vio ' + ('correctamente' if vistas[i] else 'incorrectamente'))
#
# NameError: name 'peliculas' is not defined

# %%
import pandas as pd
