# %%
print('prueba de python ')
# Out:
# prueba de python

# %%
print(type(5))
print(type(5.0))
print(type('hola'))
print(type(True))
print(type(None))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombe = 'Ivan'
edad = 30
estatura = 1.75

# %%
print(nombe)
# Out:
# Ivan

# %%
nombre = 'transformers'
anno = 2007
visto = True
print('la pelicula ' + nombre + ' del año ' + str(anno) + ' se vio ' + ('correctamente' if visto else 'pe'))
# Out:
# la pelicula transformers del año 2007 se vio correctamente

# %%
peliculas = [
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]

annos = [
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]

vistas = [
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]

# %%
for i in range(len(peliculas)):
    print('la pelicula ' + peliculas[i] + ' del año ' + str(annos[i]) + ' se vio ' + ('correctamente' if vistas[i] else 'incorrectamente'))
# Out:
# la pelicula The Shawshank Redemption del año 1994 se vio correctamente
# la pelicula The Dark Knight del año 2008 se vio incorrectamente
# la pelicula Inception del año 2010 se vio correctamente
# la pelicula Pulp Fiction del año 1994 se vio incorrectamente
# la pelicula The Matrix del año 1999 se vio correctamente
# la pelicula Interstellar del año 2014 se vio incorrectamente
# la pelicula Parasite del año 2019 se vio correctamente
# la pelicula Gladiator del año 2000 se vio incorrectamente
# la pelicula Titanic del año 1997 se vio correctamente
# la pelicula The Lord of the Rings: The Fellowship of the Ring del año 2001 se vio incorrectamente
